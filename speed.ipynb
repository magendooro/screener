# %%
from metrics import calculate_metrics, read_all_tickers
import pandas as pd 
from scipy.signal import find_peaks
import matplotlib.pyplot as plt
import datetime
import pandas_datareader as dtr
import time

data = read_all_tickers('tickers')
os.listdir()

# %%
yf_params = {
    'start':datetime.date.today() - datetime.timedelta(days = 1),
    'end':datetime.date.today(),
    'pause': .2, 
    'adjust_price':True, 
    'ret_index':False,
    'interval':'d',
    'get_actions': True,
    'adjust_dividends': True
}

# %%
# %time
tickers = [s.split('.')[0] for s in os.listdir('data/tickers')]
# Out:
# CPU times: user 1 µs, sys: 0 ns, total: 1 µs
# Wall time: 3.1 µs

# %%
tickers
# Out:
# ['TWTR',
#  'ULTA',
#  'PNC',
#  'IVZ',
#  'ATVI',
#  'GD',
#  'DTE',
#  'XOM',
#  'SNA',
#  'EBAY',
#  'TGT',
#  'PBCT',
#  'EXR',
#  'BSX',
#  'CSCO',
#  'CSX',
#  'EW',
#  'VFC',
#  'FFIV',
#  'MKC',
#  'NTAP',
#  'LUV',
#  'ES',
#  'HRL',
#  'MTCH',
#  'IPG',
#  'ALL',
#  'FMC',
#  'MLM',
#  'JKHY',
#  'ITW',
#  'GS',
#  'ICE',
#  'LVS',
#  'VNO',
#  'KLAC',
#  'WHR',
#  'STE',
#  'CPRT',
#  'HES',
#  'EOG',
#  'DHR',
#  'MAR',
#  'CVX',
#  'TMO',
#  'WMT',
#  'HD',
#  'HSY',
#  'EL',
#  'LYV',
#  'MA',
#  'CARR',
#  'VRSK',
#  'ALK',
#  'CTAS',
#  'BAX',
#  'FTV',
#  'INCY',
#  'SNPS',
#  'NKE',
#  'IR',
#  'NOW',
#  'ANSS',
#  'CDW',
#  'WRB',
#  'BLL',
#  'CLX',
#  'O',
#  'RL',
#  'CI',
#  'TDG',
#  'MGM',
#  'SBNY',
#  'FB',
#  'PCAR',
#  'HST',
#  'GOOG',
#  'MSCI',
#  'PH',
#  'GPN',
#  'IBM',
#  'LEN',
#  'RCL',
#  'AMP',
#  'LMT',
#  'MRO',
#  'VTRS',
#  'K',
#  'UAA',
#  'CNP',
#  'CMI',
#  'IFF',
#  'CCI',
#  'HUM',
#  'USB',
#  'DG',
#  'BK',
#  'DIS',
#  'TJX',
#  'AMGN',
#  'WYNN',
#  'UA',
#  'URI',
#  'CTLT',
#  'GIS',
#  'CAH',
#  'ACN',
#  'V',
#  'STX',
#  'TROW',
#  'AJG',
#  'NSC',
#  'DLR',
#  'CB',
#  'REG',
#  'ADBE',
#  'PHM',
#  'WELL',
#  'DXC',
#  'MTD',
#  'HAL',
#  'HWM',
#  'WY',
#  'PAYX',
#  'APTV',
#  'BXP',
#  'GPC',
#  'NI',
#  'SIVB',
#  'MSI',
#  'TTWO',
#  'MAS',
#  'IRM',
#  'NOC',
#  'ECL',
#  'COST',
#  'TER',
#  'LW',
#  'FISV',
#  'CFG',
#  'DOV',
#  'KMB',
#  'CHRW',
#  'GWW',
#  'AAP',
#  'AVY',
#  'RJF',
#  'FDS',
#  'EA',
#  'JNPR',
#  'SRE',
#  'MOH',
#  'PG',
#  'DLTR',
#  'TECH',
#  'PVH',
#  'D',
#  'FRT',
#  'LIN',
#  'IPGP',
#  'ZBH',
#  'ZION',
#  'SO',
#  'NCLH',
#  'GOOGL',
#  'ALGN',
#  'TT',
#  'TFX',
#  'FE',
#  'ETN',
#  'SHW',
#  'MPC',
#  'APH',
#  'DFS',
#  'ANTM',
#  'PAYC',
#  'AMAT',
#  'AMD',
#  'CDAY',
#  'VTR',
#  'CMCSA',
#  'STZ',
#  'ETR',
#  'NXPI',
#  'TYL',
#  'WM',
#  'LOW',
#  'ETSY',
#  'HPE',
#  'WAB',
#  'PEG',
#  'PENN',
#  'KMX',
#  'NWL',
#  'SWK',
#  'INTC',
#  'KHC',
#  'AES',
#  'ARE',
#  'LYB',
#  'HPQ',
#  'TAP',
#  'CVS',
#  'CBRE',
#  'AAPL',
#  'ZBRA',
#  'EMN',
#  'DUK',
#  'BBY',
#  'MET',
#  'WMB',
#  'CME',
#  'CBOE',
#  'SJM',
#  'SPGI',
#  'TSLA',
#  'FOX',
#  'VRTX',
#  'QRVO',
#  'NUE',
#  'REGN',
#  'VMC',
#  'AVGO',
#  'MAA',
#  'POOL',
#  'BA',
#  'KO',
#  'CTRA',
#  'NWS',
#  'VRSN',
#  'DE',
#  'PKG',
#  'HIG',
#  'CZR',
#  'CERN',
#  'KEY',
#  'J',
#  'LDOS',
#  'UDR',
#  'FAST',
#  'PNR',
#  'AVB',
#  'MCD',
#  'TDY',
#  'F',
#  'HAS',
#  'WDC',
#  'TSN',
#  'AWK',
#  'PPL',
#  'DRE',
#  'MKTX',
#  'DOW',
#  'PKI',
#  'RF',
#  'AMT',
#  'PRU',
#  'GE',
#  'BMY',
#  'CINF',
#  'PARA',
#  'RSG',
#  'MMM',
#  'CAG',
#  'MDT',
#  'HOLX',
#  'EXPE',
#  'XEL',
#  'EIX',
#  'PLD',
#  'TEL',
#  'MU',
#  'MS',
#  'MDLZ',
#  'KIM',
#  'EXPD',
#  'IEX',
#  'FBHS',
#  'NDSN',
#  'PXD',
#  'FLT',
#  'GILD',
#  'A',
#  'SBAC',
#  'AAL',
#  'C',
#  'BKR',
#  'BAC',
#  'GNRC',
#  'NVR',
#  'NEE',
#  'CHTR',
#  'ABC',
#  'CTSH',
#  'AOS',
#  'PEP',
#  'HON',
#  'SBUX',
#  'TPR',
#  'MRNA',
#  'EMR',
#  'YUM',
#  'JBHT',
#  'JPM',
#  'MCK',
#  'DAL',
#  'T',
#  'ORCL',
#  'TMUS',
#  'PGR',
#  'WTW',
#  'CRL',
#  'KR',
#  'ROL',
#  'NRG',
#  'CCL',
#  'BDX',
#  'JNJ',
#  'OKE',
#  'CTXS',
#  'UNP',
#  'IDXX',
#  'AIZ',
#  'ED',
#  'HCA',
#  'LUMN',
#  'ABMD',
#  'NTRS',
#  'HLT',
#  'WFC',
#  'GL',
#  'UPS',
#  'FIS',
#  'PEAK',
#  'SYF',
#  'TFC',
#  'SYK',
#  'QCOM',
#  'EPAM',
#  'DVA',
#  'EXC',
#  'OMC',
#  'OTIS',
#  'ANET',
#  'AZO',
#  'HII',
#  'UHS',
#  'LHX',
#  'SLB',
#  'CNC',
#  'GRMN',
#  'APD',
#  'BIO',
#  'NEM',
#  'KEYS',
#  'MPWR',
#  'WAT',
#  'TRMB',
#  'TXT',
#  'ODFL',
#  'NDAQ',
#  'AXP',
#  'DD',
#  'MCO',
#  'PFG',
#  'BIIB',
#  'ADP',
#  'FTNT',
#  'UAL',
#  'GLW',
#  'IP',
#  'AEP',
#  'JCI',
#  'UNH',
#  'NVDA',
#  'CMA',
#  'SWKS',
#  'BR',
#  'DISH',
#  'SYY',
#  'WRK',
#  'TXN',
#  'ATO',
#  'OGN',
#  'PNW',
#  'CMG',
#  'NLSN',
#  'DPZ',
#  'ROST',
#  'IQV',
#  'ALLE',
#  'ADI',
#  'ADM',
#  'DHI',
#  'ROK',
#  'LKQ',
#  'XYL',
#  'INTU',
#  'COF',
#  'DRI',
#  'ISRG',
#  'FRC',
#  'BBWI',
#  'APA',
#  'EVRG',
#  'GM',
#  'MMC',
#  'NWSA',
#  'CDNS',
#  'TSCO',
#  'ALB',
#  'MRK',
#  'ADSK',
#  'PWR',
#  'OXY',
#  'L',
#  'PPG',
#  'CMS',
#  'LH',
#  'FCX',
#  'SPG',
#  'AFL',
#  'CE',
#  'DVN',
#  'DISCA',
#  'FDX',
#  'CRM',
#  'ROP',
#  'KMI',
#  'WEC',
#  'BWA',
#  'MCHP',
#  'AEE',
#  'ESS',
#  'EQIX',
#  'FANG',
#  'SEDG',
#  'AMCR',
#  'PSX',
#  'CHD',
#  'WST',
#  'CL',
#  'MOS',
#  'AIG',
#  'SCHW',
#  'BEN',
#  'HBAN',
#  'IT',
#  'NFLX',
#  'PYPL',
#  'RTX',
#  'PTC',
#  'COP',
#  'PM',
#  'LRCX',
#  'MSFT',
#  'BLK',
#  'AKAM',
#  'LNC',
#  'BKNG',
#  'LLY',
#  'MHK',
#  'CPB',
#  'DXCM',
#  'AME',
#  'EQR',
#  'STT',
#  'RE',
#  'ZTS',
#  'ABT',
#  'MO',
#  'VLO',
#  'FITB',
#  'MNST',
#  'LNT',
#  'TRV',
#  'AMZN',
#  'DISCK',
#  'PSA',
#  'SEE',
#  'CTVA',
#  'MTB',
#  'EFX',
#  'COO',
#  'DGX',
#  'AON',
#  'RHI',
#  'ABBV',
#  'BRO',
#  'NLOK',
#  'CAT',
#  'RMD',
#  'WBA',
#  'ORLY',
#  'HSIC',
#  'FOXA',
#  'CF',
#  'ILMN',
#  'ENPH',
#  'XRAY',
#  'VZ',
#  'PFE']

# %%
# %time
df = dtr.get_data_yahoo(symbols = tickers, **yf_params)
# Out:
# CPU times: user 2 µs, sys: 0 ns, total: 2 µs
# Wall time: 3.34 µs
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /home/hdd_n/Desktop/hnnaharendt/screener/speed.ipynb Cell 5' in <cell line: 2>()
#       <a href='vscode-notebook-cell:/home/hdd_n/Desktop/hnnaharendt/screener/speed.ipynb#ch0000004?line=0'>1</a> get_ipython().run_line_magic('time', '')
# ----> <a href='vscode-notebook-cell:/home/hdd_n/Desktop/hnnaharendt/screener/speed.ipynb#ch0000004?line=1'>2</a> df = dtr.get_data_yahoo(symbols = tickers, **yf_params)
#
# File ~/mambaforge/envs/stocks_env/lib/python3.10/site-packages/pandas_datareader/data.py:80, in get_data_yahoo(*args, **kwargs)
#      <a href='file:///~/mambaforge/envs/stocks_env/lib/python3.10/site-packages/pandas_datareader/data.py?line=78'>79</a> def get_data_yahoo(*args, **kwargs):
# ---> <a href='file:///~/mambaforge/envs/stocks_env/lib/python3.10/site-packages/pandas_datareader/data.py?line=79'>80</a>     return YahooDailyReader(*args, **kwargs).read()
#
# File ~/mambaforge/envs/stocks_env/lib/python3.10/site-packages/pandas_datareader/base.py:258, in _DailyBaseReader.read(self)
#     <a href='file:///~/mambaforge/envs/stocks_env/lib/python3.10/site-packages/pandas_datareader/base.py?line=255'>256</a>     df = self._dl_mult_symbols(self.symbols.index)
#     <a href='file:///~/mambaforge/envs/stocks_env/lib/python3.10/site-packages/pandas_datareader/base.py?line=256'>257</a> else:
# --> <a href='file:///~/mambaforge/envs/stocks_env/lib/python3.10/site-packages/pandas_datareader/base.py?line=257'>258</a>     df = self._dl_mult_symbols(self.symbols)
#     <a href='file:///~/mambaforge/envs/stocks_env/lib/python3.10/site-packages/pandas_datareader/base.py?line=258'>259</a> return df
#
# File ~/mambaforge/envs/stocks_env/lib/python3.10/site-packages/pandas_datareader/base.py:285, in _DailyBaseReader._dl_mult_symbols(self, symbols)
#     <a href='file:///~/mambaforge/envs/stocks_env/lib/python3.10/site-packages/pandas_datareader/base.py?line=282'>283</a>         stocks[sym] = df_na
#     <a href='file:///~/mambaforge/envs/stocks_env/lib/python3.10/site-packages/pandas_datareader/base.py?line=283'>284</a> if PANDAS_0230:
# --> <a href='file:///~/mambaforge/envs/stocks_env/lib/python3.10/site-packages/pandas_datareader/base.py?line=284'>285</a>     result = concat(stocks, sort=True).unstack(level=0)
#     <a href='file:///~/mambaforge/envs/stocks_env/lib/python3.10/site-packages/pandas_datareader/base.py?line=285'>286</a> else:
#     <a href='file:///~/mambaforge/envs/stocks_env/lib/python3.10/site-packages/pandas_datareader/base.py?line=286'>287</a>     result = concat(stocks).unstack(level=0)
#
# File ~/mambaforge/envs/stocks_env/lib/python3.10/site-packages/pandas/core/frame.py:8413, in DataFrame.unstack(self, level, fill_value)
#    <a href='file:///~/mambaforge/envs/stocks_env/lib/python3.10/site-packages/pandas/core/frame.py?line=8350'>8351</a> """
#    <a href='file:///~/mambaforge/envs/stocks_env/lib/python3.10/site-packages/pandas/core/frame.py?line=8351'>8352</a> Pivot a level of the (necessarily hierarchical) index labels.
#    <a href='file:///~/mambaforge/envs/stocks_env/lib/python3.10/site-packages/pandas/core/frame.py?line=8352'>8353</a>
#    (...)
#    <a href='file:///~/mambaforge/envs/stocks_env/lib/python3.10/site-packages/pandas/core/frame.py?line=8408'>8409</a> dtype: float64
#    <a href='file:///~/mambaforge/envs/stocks_env/lib/python3.10/site-packages/pandas/core/frame.py?line=8409'>8410</a> """
#    <a href='file:///~/mambaforge/envs/stocks_env/lib/python3.10/site-packages/pandas/core/frame.py?line=8410'>8411</a> from pandas.core.reshape.reshape import unstack
# -> <a href='file:///~/mambaforge/envs/stocks_env/lib/python3.10/site-packages/pandas/core/frame.py?line=8412'>8413</a> result = unstack(self, level, fill_value)
#    <a href='file:///~/mambaforge/envs/stocks_env/lib/python3.10/site-packages/pandas/core/frame.py?line=8414'>8415</a> return result.__finalize__(self, method="unstack")
#
# File ~/mambaforge/envs/stocks_env/lib/python3.10/site-packages/pandas/core/reshape/reshape.py:478, in unstack(obj, level, fill_value)
#     <a href='file:///~/mambaforge/envs/stocks_env/lib/python3.10/site-packages/pandas/core/reshape/reshape.py?line=475'>476</a> if isinstance(obj, DataFrame):
#     <a href='file:///~/mambaforge/envs/stocks_env/lib/python3.10/site-packages/pandas/core/reshape/reshape.py?line=476'>477</a>     if isinstance(obj.index, MultiIndex):
# --> <a href='file:///~/mambaforge/envs/stocks_env/lib/python3.10/site-packages/pandas/core/reshape/reshape.py?line=477'>478</a>         return _unstack_frame(obj, level, fill_value=fill_value)
#     <a href='file:///~/mambaforge/envs/stocks_env/lib/python3.10/site-packages/pandas/core/reshape/reshape.py?line=478'>479</a>     else:
#     <a href='file:///~/mambaforge/envs/stocks_env/lib/python3.10/site-packages/pandas/core/reshape/reshape.py?line=479'>480</a>         return obj.T.stack(dropna=False)
#
# File ~/mambaforge/envs/stocks_env/lib/python3.10/site-packages/pandas/core/reshape/reshape.py:501, in _unstack_frame(obj, level, fill_value)
#     <a href='file:///~/mambaforge/envs/stocks_env/lib/python3.10/site-packages/pandas/core/reshape/reshape.py?line=498'>499</a> def _unstack_frame(obj, level, fill_value=None):
#     <a href='file:///~/mambaforge/envs/stocks_env/lib/python3.10/site-packages/pandas/core/reshape/reshape.py?line=499'>500</a>     if not obj._can_fast_transpose:
# --> <a href='file:///~/mambaforge/envs/stocks_env/lib/python3.10/site-packages/pandas/core/reshape/reshape.py?line=500'>501</a>         unstacker = _Unstacker(obj.index, level=level)
#     <a href='file:///~/mambaforge/envs/stocks_env/lib/python3.10/site-packages/pandas/core/reshape/reshape.py?line=501'>502</a>         mgr = obj._mgr.unstack(unstacker, fill_value=fill_value)
#     <a href='file:///~/mambaforge/envs/stocks_env/lib/python3.10/site-packages/pandas/core/reshape/reshape.py?line=502'>503</a>         return obj._constructor(mgr)
#
# File ~/mambaforge/envs/stocks_env/lib/python3.10/site-packages/pandas/core/reshape/reshape.py:140, in _Unstacker.__init__(self, index, level, constructor)
#     <a href='file:///~/mambaforge/envs/stocks_env/lib/python3.10/site-packages/pandas/core/reshape/reshape.py?line=132'>133</a> if num_cells > np.iinfo(np.int32).max:
#     <a href='file:///~/mambaforge/envs/stocks_env/lib/python3.10/site-packages/pandas/core/reshape/reshape.py?line=133'>134</a>     warnings.warn(
#     <a href='file:///~/mambaforge/envs/stocks_env/lib/python3.10/site-packages/pandas/core/reshape/reshape.py?line=134'>135</a>         f"The following operation may generate {num_cells} cells "
#     <a href='file:///~/mambaforge/envs/stocks_env/lib/python3.10/site-packages/pandas/core/reshape/reshape.py?line=135'>136</a>         f"in the resulting pandas object.",
#     <a href='file:///~/mambaforge/envs/stocks_env/lib/python3.10/site-packages/pandas/core/reshape/reshape.py?line=136'>137</a>         PerformanceWarning,
#     <a href='file:///~/mambaforge/envs/stocks_env/lib/python3.10/site-packages/pandas/core/reshape/reshape.py?line=137'>138</a>     )
# --> <a href='file:///~/mambaforge/envs/stocks_env/lib/python3.10/site-packages/pandas/core/reshape/reshape.py?line=139'>140</a> self._make_selectors()
#
# File ~/mambaforge/envs/stocks_env/lib/python3.10/site-packages/pandas/core/reshape/reshape.py:192, in _Unstacker._make_selectors(self)
#     <a href='file:///~/mambaforge/envs/stocks_env/lib/python3.10/site-packages/pandas/core/reshape/reshape.py?line=188'>189</a> mask.put(selector, True)
#     <a href='file:///~/mambaforge/envs/stocks_env/lib/python3.10/site-packages/pandas/core/reshape/reshape.py?line=190'>191</a> if mask.sum() < len(self.index):
# --> <a href='file:///~/mambaforge/envs/stocks_env/lib/python3.10/site-packages/pandas/core/reshape/reshape.py?line=191'>192</a>     raise ValueError("Index contains duplicate entries, cannot reshape")
#     <a href='file:///~/mambaforge/envs/stocks_env/lib/python3.10/site-packages/pandas/core/reshape/reshape.py?line=193'>194</a> self.group_index = comp_index
#     <a href='file:///~/mambaforge/envs/stocks_env/lib/python3.10/site-packages/pandas/core/reshape/reshape.py?line=194'>195</a> self.mask = mask
#
# ValueError: Index contains duplicate entries, cannot reshape

# %%
import yfinance as yf

# %%
tickers_ = yf.Tickers()

# %%
" ".join(tickers)
# Out:
# 'TWTR ULTA PNC IVZ ATVI GD DTE XOM SNA EBAY TGT PBCT EXR BSX CSCO CSX EW VFC FFIV MKC NTAP LUV ES HRL MTCH IPG ALL FMC MLM JKHY ITW GS ICE LVS VNO KLAC WHR STE CPRT HES EOG DHR MAR CVX TMO WMT HD HSY EL LYV MA CARR VRSK ALK CTAS BAX FTV INCY SNPS NKE IR NOW ANSS CDW WRB BLL CLX O RL CI TDG MGM SBNY FB PCAR HST GOOG MSCI PH GPN IBM LEN RCL AMP LMT MRO VTRS K UAA CNP CMI IFF CCI HUM USB DG BK DIS TJX AMGN WYNN UA URI CTLT GIS CAH ACN V STX TROW AJG NSC DLR CB REG ADBE PHM WELL DXC MTD HAL HWM WY PAYX APTV BXP GPC NI SIVB MSI TTWO MAS IRM NOC ECL COST TER LW FISV CFG DOV KMB CHRW GWW AAP AVY RJF FDS EA JNPR SRE MOH PG DLTR TECH PVH D FRT LIN IPGP ZBH ZION SO NCLH GOOGL ALGN TT TFX FE ETN SHW MPC APH DFS ANTM PAYC AMAT AMD CDAY VTR CMCSA STZ ETR NXPI TYL WM LOW ETSY HPE WAB PEG PENN KMX NWL SWK INTC KHC AES ARE LYB HPQ TAP CVS CBRE AAPL ZBRA EMN DUK BBY MET WMB CME CBOE SJM SPGI TSLA FOX VRTX QRVO NUE REGN VMC AVGO MAA POOL BA KO CTRA NWS VRSN DE PKG HIG CZR CERN KEY J LDOS UDR FAST PNR AVB MCD TDY F HAS WDC TSN AWK PPL DRE MKTX DOW PKI RF AMT PRU GE BMY CINF PARA RSG MMM CAG MDT HOLX EXPE XEL EIX PLD TEL MU MS MDLZ KIM EXPD IEX FBHS NDSN PXD FLT GILD A SBAC AAL C BKR BAC GNRC NVR NEE CHTR ABC CTSH AOS PEP HON SBUX TPR MRNA EMR YUM JBHT JPM MCK DAL T ORCL TMUS PGR WTW CRL KR ROL NRG CCL BDX JNJ OKE CTXS UNP IDXX AIZ ED HCA LUMN ABMD NTRS HLT WFC GL UPS FIS PEAK SYF TFC SYK QCOM EPAM DVA EXC OMC OTIS ANET AZO HII UHS LHX SLB CNC GRMN APD BIO NEM KEYS MPWR WAT TRMB TXT ODFL NDAQ AXP DD MCO PFG BIIB ADP FTNT UAL GLW IP AEP JCI UNH NVDA CMA SWKS BR DISH SYY WRK TXN ATO OGN PNW CMG NLSN DPZ ROST IQV ALLE ADI ADM DHI ROK LKQ XYL INTU COF DRI ISRG FRC BBWI APA EVRG GM MMC NWSA CDNS TSCO ALB MRK ADSK PWR OXY L PPG CMS LH FCX SPG AFL CE DVN DISCA FDX CRM ROP KMI WEC BWA MCHP AEE ESS EQIX FANG SEDG AMCR PSX CHD WST CL MOS AIG SCHW BEN HBAN IT NFLX PYPL RTX PTC COP PM LRCX MSFT BLK AKAM LNC BKNG LLY MHK CPB DXCM AME EQR STT RE ZTS ABT MO VLO FITB MNST LNT TRV AMZN DISCK PSA SEE CTVA MTB EFX COO DGX AON RHI ABBV BRO NLOK CAT RMD WBA ORLY HSIC FOXA CF ILMN ENPH XRAY VZ PFE'

# %%
yf_ticker = yf.Tickers(" ".join(tickers))

# %%
yf_ticker
# Out:
# yfinance.Tickers object <TWTR,ULTA,PNC,IVZ,ATVI,GD,DTE,XOM,SNA,EBAY,TGT,PBCT,EXR,BSX,CSCO,CSX,EW,VFC,FFIV,MKC,NTAP,LUV,ES,HRL,MTCH,IPG,ALL,FMC,MLM,JKHY,ITW,GS,ICE,LVS,VNO,KLAC,WHR,STE,CPRT,HES,EOG,DHR,MAR,CVX,TMO,WMT,HD,HSY,EL,LYV,MA,CARR,VRSK,ALK,CTAS,BAX,FTV,INCY,SNPS,NKE,IR,NOW,ANSS,CDW,WRB,BLL,CLX,O,RL,CI,TDG,MGM,SBNY,FB,PCAR,HST,GOOG,MSCI,PH,GPN,IBM,LEN,RCL,AMP,LMT,MRO,VTRS,K,UAA,CNP,CMI,IFF,CCI,HUM,USB,DG,BK,DIS,TJX,AMGN,WYNN,UA,URI,CTLT,GIS,CAH,ACN,V,STX,TROW,AJG,NSC,DLR,CB,REG,ADBE,PHM,WELL,DXC,MTD,HAL,HWM,WY,PAYX,APTV,BXP,GPC,NI,SIVB,MSI,TTWO,MAS,IRM,NOC,ECL,COST,TER,LW,FISV,CFG,DOV,KMB,CHRW,GWW,AAP,AVY,RJF,FDS,EA,JNPR,SRE,MOH,PG,DLTR,TECH,PVH,D,FRT,LIN,IPGP,ZBH,ZION,SO,NCLH,GOOGL,ALGN,TT,TFX,FE,ETN,SHW,MPC,APH,DFS,ANTM,PAYC,AMAT,AMD,CDAY,VTR,CMCSA,STZ,ETR,NXPI,TYL,WM,LOW,ETSY,HPE,WAB,PEG,PENN,KMX,NWL,SWK,INTC,KHC,AES,ARE,LYB,HPQ,TAP,CVS,CBRE,AAPL,ZBRA,EMN,DUK,BBY,MET,WMB,CME,CBOE,SJM,SPGI,TSLA,FOX,VRTX,QRVO,NUE,REGN,VMC,AVGO,MAA,POOL,BA,KO,CTRA,NWS,VRSN,DE,PKG,HIG,CZR,CERN,KEY,J,LDOS,UDR,FAST,PNR,AVB,MCD,TDY,F,HAS,WDC,TSN,AWK,PPL,DRE,MKTX,DOW,PKI,RF,AMT,PRU,GE,BMY,CINF,PARA,RSG,MMM,CAG,MDT,HOLX,EXPE,XEL,EIX,PLD,TEL,MU,MS,MDLZ,KIM,EXPD,IEX,FBHS,NDSN,PXD,FLT,GILD,A,SBAC,AAL,C,BKR,BAC,GNRC,NVR,NEE,CHTR,ABC,CTSH,AOS,PEP,HON,SBUX,TPR,MRNA,EMR,YUM,JBHT,JPM,MCK,DAL,T,ORCL,TMUS,PGR,WTW,CRL,KR,ROL,NRG,CCL,BDX,JNJ,OKE,CTXS,UNP,IDXX,AIZ,ED,HCA,LUMN,ABMD,NTRS,HLT,WFC,GL,UPS,FIS,PEAK,SYF,TFC,SYK,QCOM,EPAM,DVA,EXC,OMC,OTIS,ANET,AZO,HII,UHS,LHX,SLB,CNC,GRMN,APD,BIO,NEM,KEYS,MPWR,WAT,TRMB,TXT,ODFL,NDAQ,AXP,DD,MCO,PFG,BIIB,ADP,FTNT,UAL,GLW,IP,AEP,JCI,UNH,NVDA,CMA,SWKS,BR,DISH,SYY,WRK,TXN,ATO,OGN,PNW,CMG,NLSN,DPZ,ROST,IQV,ALLE,ADI,ADM,DHI,ROK,LKQ,XYL,INTU,COF,DRI,ISRG,FRC,BBWI,APA,EVRG,GM,MMC,NWSA,CDNS,TSCO,ALB,MRK,ADSK,PWR,OXY,L,PPG,CMS,LH,FCX,SPG,AFL,CE,DVN,DISCA,FDX,CRM,ROP,KMI,WEC,BWA,MCHP,AEE,ESS,EQIX,FANG,SEDG,AMCR,PSX,CHD,WST,CL,MOS,AIG,SCHW,BEN,HBAN,IT,NFLX,PYPL,RTX,PTC,COP,PM,LRCX,MSFT,BLK,AKAM,LNC,BKNG,LLY,MHK,CPB,DXCM,AME,EQR,STT,RE,ZTS,ABT,MO,VLO,FITB,MNST,LNT,TRV,AMZN,DISCK,PSA,SEE,CTVA,MTB,EFX,COO,DGX,AON,RHI,ABBV,BRO,NLOK,CAT,RMD,WBA,ORLY,HSIC,FOXA,CF,ILMN,ENPH,XRAY,VZ,PFE>

# %%
yesterday = yf_ticker.download(interval='1d', start = yf_params['start'], end = yf_params['end'], timeout = 2)
# Out:
# [*********************100%***********************]  502 of 502 completed

# %%
yesterday
# Out:
#                  Close                                                 \
#                      A        AAL         AAP        AAPL        ABBV
# Date
# 2022-03-23  134.179993  16.209999  213.339996  170.210007  158.419998
# 2022-03-24  136.410004  16.719999  214.669998  174.070007  160.279999
#
#                                                                         ...  \
#                    ABC        ABMD         ABT         ACN        ADBE  ...
# Date                                                                    ...
# 2022-03-23  151.529999  311.029999  116.919998  320.500000  422.899994  ...
# 2022-03-24  152.610001  321.470001  117.820000  325.290009  432.140015  ...
#
#              Volume                                                         \
#                WYNN      XEL       XOM     XRAY      XYL      YUM      ZBH
# Date
# 2022-03-23  1636700  2511300  27716300  1584900  1819800  1798900  2420000
# 2022-03-24  2593500  2257800  19860900  1350300  1075600  1858300  2393500
#
#
#               ZBRA     ZION      ZTS
# Date
# 2022-03-23  325800  1498600  2115200
# 2022-03-24  311000  1329500  3445900
#
# [2 rows x 3514 columns]

# %%
yesterday.axes
# Out:
# [DatetimeIndex(['2022-03-23', '2022-03-24'], dtype='datetime64[ns]', name='Date', freq=None),
#  MultiIndex([( 'Close',    'A'),
#              ( 'Close',  'AAL'),
#              ( 'Close',  'AAP'),
#              ( 'Close', 'AAPL'),
#              ( 'Close', 'ABBV'),
#              ( 'Close',  'ABC'),
#              ( 'Close', 'ABMD'),
#              ( 'Close',  'ABT'),
#              ( 'Close',  'ACN'),
#              ( 'Close', 'ADBE'),
#              ...
#              ('Volume', 'WYNN'),
#              ('Volume',  'XEL'),
#              ('Volume',  'XOM'),
#              ('Volume', 'XRAY'),
#              ('Volume',  'XYL'),
#              ('Volume',  'YUM'),
#              ('Volume',  'ZBH'),
#              ('Volume', 'ZBRA'),
#              ('Volume', 'ZION'),
#              ('Volume',  'ZTS')],
#             length=3514)]

# %%
yesterday.keys()
# Out:
# MultiIndex([( 'Close',    'A'),
#             ( 'Close',  'AAL'),
#             ( 'Close',  'AAP'),
#             ( 'Close', 'AAPL'),
#             ( 'Close', 'ABBV'),
#             ( 'Close',  'ABC'),
#             ( 'Close', 'ABMD'),
#             ( 'Close',  'ABT'),
#             ( 'Close',  'ACN'),
#             ( 'Close', 'ADBE'),
#             ...
#             ('Volume', 'WYNN'),
#             ('Volume',  'XEL'),
#             ('Volume',  'XOM'),
#             ('Volume', 'XRAY'),
#             ('Volume',  'XYL'),
#             ('Volume',  'YUM'),
#             ('Volume',  'ZBH'),
#             ('Volume', 'ZBRA'),
#             ('Volume', 'ZION'),
#             ('Volume',  'ZTS')],
#            length=3514)

# %%
yesterday['Close']
# Out:
#                      A        AAL         AAP        AAPL        ABBV  \
# Date
# 2022-03-23  134.179993  16.209999  213.339996  170.210007  158.419998
# 2022-03-24  136.410004  16.719999  214.669998  174.070007  160.279999
#
#                    ABC        ABMD         ABT         ACN        ADBE  ...  \
# Date                                                                    ...
# 2022-03-23  151.529999  311.029999  116.919998  320.500000  422.899994  ...
# 2022-03-24  152.610001  321.470001  117.820000  325.290009  432.140015  ...
#
#                  WYNN        XEL        XOM       XRAY        XYL         YUM  \
# Date
# 2022-03-23  78.639999  69.300003  83.129997  49.490002  86.540001  115.959999
# 2022-03-24  81.370003  69.879997  83.379997  49.189999  86.339996  119.699997
#
#                    ZBH        ZBRA       ZION         ZTS
# Date
# 2022-03-23  120.739998  419.910004  67.699997  191.229996
# 2022-03-24  124.150002  427.369995  68.580002  189.570007
#
# [2 rows x 502 columns]
